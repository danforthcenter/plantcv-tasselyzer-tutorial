# %%
# Install PlantCV and required dependencies
# %pip install "altair>=5" ipympl plantcv

# Give access and mount your Google Drive (need a Google Account)
# Change path to directory you wish output files to be saved to.
from google.colab import drive
drive.mount('/content/gdrive')

# Enable widget feature with matplotlib
from google.colab import output
output.enable_custom_widget_manager()

#View working directory, may need to change path
# %pwd
# Out:
# Requirement already satisfied: altair>=5 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (5.5.0)
# Requirement already satisfied: ipympl in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (0.9.7)
# Requirement already satisfied: plantcv in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (4.8.dev112+ga98789c2)
# Requirement already satisfied: jinja2 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from altair>=5) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from altair>=5) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from altair>=5) (1.41.0)
# Requirement already satisfied: packaging in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from altair>=5) (25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from altair>=5) (4.13.2)
# Requirement already satisfied: ipython<10 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipympl) (9.3.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipympl) (8.1.7)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipympl) (3.10.3)
# Requirement already satisfied: numpy in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipympl) (2.2.6)
# Requirement already satisfied: pillow in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipympl) (11.2.1)
# Requirement already satisfied: traitlets<6 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipython<10->ipympl) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipython<10->ipympl) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipython<10->ipympl) (2.19.1)
# Requirement already satisfied: stack_data in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: pandas in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (2.2.3)
# Requirement already satisfied: scipy in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (1.15.2)
# Requirement already satisfied: scikit-image>=0.19 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (0.25.2)
# Requirement already satisfied: scikit-learn in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (1.6.1)
# Requirement already satisfied: dask in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (2025.5.1)
# Requirement already satisfied: dask-jobqueue in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (0.9.0)
# Requirement already satisfied: opencv-python in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (4.11.0)
# Requirement already satisfied: xarray>=2022.11.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (2025.4.0)
# Requirement already satisfied: statsmodels in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (0.14.4)
# Requirement already satisfied: vl-convert-python in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from plantcv) (1.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=5) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=5) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=5) (0.25.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from scikit-image>=0.19->plantcv) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from scikit-image>=0.19->plantcv) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from scikit-image>=0.19->plantcv) (2025.6.1)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from scikit-image>=0.19->plantcv) (0.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from pandas->plantcv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from pandas->plantcv) (2025.2)
# Requirement already satisfied: click>=8.1 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from dask->plantcv) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from dask->plantcv) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from dask->plantcv) (2025.5.1)
# Requirement already satisfied: partd>=1.4.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from dask->plantcv) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from dask->plantcv) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from dask->plantcv) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from dask->plantcv) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from importlib_metadata>=4.13.0->dask->plantcv) (3.22.0)
# Requirement already satisfied: locket in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from partd>=1.4.0->dask->plantcv) (1.0.0)
# Requirement already satisfied: distributed>=2022.02.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from dask-jobqueue->plantcv) (2025.5.1)
# Requirement already satisfied: msgpack>=1.0.2 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (7.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (6.5.1)
# Requirement already satisfied: urllib3>=1.26.5 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.4.0)
# Requirement already satisfied: zict>=3.0.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from jinja2->altair>=5) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from scikit-learn->plantcv) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from scikit-learn->plantcv) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from stack_data->ipython<10->ipympl) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from stack_data->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from stack_data->ipython<10->ipympl) (0.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/slama/miniforge3/envs/plantcv-an/lib/python3.11/site-packages (from statsmodels->plantcv) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       2 get_ipython().run_line_magic('pip', 'install "altair>=5" ipympl plantcv')
#       4 # Give access and mount your Google Drive (need a Google Account)
#       5 # Change path to directory you wish output files to be saved to.
# ----> 6 from google.colab import drive
#       7 drive.mount('/content/gdrive')
#       9 # Enable widget feature with matplotlib
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# # Tasselyzer Tutorial
#
# **Author**: Chong Teng
#
# **Updates by**: Haley Schuhl
# **Updated on**: 18 December, 2024
#
# Tasselyzer, a machine learning method to quantify anther extrusion in maize based on PlantCV.

# %%
# import packages
# inline to avoid interactive mode; widget to activate interactive mode;
# %matplotlib inline
from plantcv import plantcv as pcv
import numpy as np
import os

# %% [markdown]
# The options class stands in for the command-line argument parser function used when running PlantCV workflows in parallel

# %%
# Input/output options
class options:
    def __init__(self):
        self.image = "2-6.jpg"  # required
        self.debug = "plot"  # None, "print" (save to file), or "plot" (display in notebook)
        self.writeimg = True
        self.result = "2-6.csv"  # required
        self.outdir = "." # Store the output to the current directory 
        self.pdfs = "out2_6.txt"

# Get options
args = options()

# %% [markdown]
# `pcv.params` can be used to set global parameters for PlantCV

# %%
# Set debug to the global parameter 
pcv.params.debug = args.debug
# Change display settings
pcv.params.dpi = 150
pcv.params.text_size = 10

# %% [markdown]
# Read in a color image

# %%
img = pcv.io.open_url(url="https://raw.githubusercontent.com/danforthcenter/plantcv-tasselyzer-tutorial/main/2-6.jpg")

# %% [markdown]
# Use the pretrained model to classify the pixels into three classes: the background (Dark), glum and branch (Green), and anthers (Anther)

# %%
masks = pcv.naive_bayes_classifier(rgb_img=img, pdf_file=args.pdfs)

# %% [markdown]
# Overlay masks "Anther" and "Green" (Glum and branch)

# %%
merged = pcv.visualize.colorize_masks(masks=[masks["Anther"], masks["Green"]], colors=["fuchsia", "green"])

# %% [markdown]
# Fill small objects for "Anther" to clean up the mask

# %%
mask_anther = pcv.fill(bin_img=masks["Anther"], size=100)

# %% [markdown]
# Fill small objects for "Green" to clean up the mask

# %%
mask_glum = pcv.fill(bin_img=masks["Green"], size=200)

# %% [markdown]
# Create custom measurements:
#
# ```
# anther_sum         = count of the number of pixels identified as anther
# glum_branch_sum    = count of the number of pixels identified as glum and branch
# anther_total_ratio = ratio of anther pixels to total anther + glum and branch pixels
# ```
#
# Print out the results and save them as custom observations in PlantCV.

# %%
# ratio
anther_sum = np.count_nonzero(mask_anther)
glum_branch_sum = np.count_nonzero(mask_glum) 
anther_total_ratio = anther_sum / float(anther_sum + glum_branch_sum)
glum_branch_total_ratio = 1 - anther_total_ratio
print('anther sum', anther_sum)
print('glum and branch sum', glum_branch_sum)
print('anther total ratio', anther_total_ratio)
print('glum and branch to total ratio', glum_branch_total_ratio)

pcv.outputs.add_observation(sample="default", variable="anther_sum", trait="anther sum", method="PlantCV naive Bayes classifier", 
                            scale="pixels", datatype=int, value=anther_sum, label="pixels")
pcv.outputs.add_observation(sample="default", variable="glum_branch_sum", trait="glum and branch sum", method="PlantCV naive Bayes classifier", 
                            scale="pixels", datatype=int, value=glum_branch_sum, label="pixels")
pcv.outputs.add_observation(sample="default", variable="anther_total_ratio", trait="anther total ratio", method="PlantCV naive Bayes classifier", 
                            scale="pixels", datatype=float, value=anther_total_ratio, label="pixels")
pcv.outputs.add_observation(sample="default", variable="glum_branch_total_ratio", trait="glum and branch to total ratio", method="PlantCV naive Bayes classifier", 
                            scale="pixels", datatype=float, value=glum_branch_total_ratio, label="pixels")
# Out:
# anther sum 288453
# glum and branch sum 128607
# anther total ratio 0.6916342972234211
# glum and branch to total ratio 0.30836570277657893

# %%
overlay = pcv.visualize.overlay_two_imgs(img1=img, img2=merged, alpha=0.7)

# %% [markdown]
# Save the results and overlay image.

# %%
if args.writeimg:
    pcv.print_image(img=overlay, filename=os.path.join(args.outdir, f"overlay_{filename}"))
pcv.outputs.save_results(filename=args.result, outformat="json")
